# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('2017-01-avon-and-somerset-street.csv')
df.head(20)
df1 = pd.read_csv('2017-01-cleveland-street.csv')
df1.head()
df = df.append(df1)
df.head()
# Out:
#                                             Crime ID    Month  \
# 0  e87d48c72a99bc0dcccd17bfade3d5e2aaae6cb6ab5c57...  2017-01
# 1  9500972e2e3c87dc23b65885dd61085ee8a39329c03792...  2017-01
# 2  052b551445726eeac6f504dfaa2d32c184b9877b81e82e...  2017-01
# 3  8e6ae250f68623b82068cd3c79b64b05a559f6d9c9393c...  2017-01
# 4  2183c598f1727df485b41f8414f7b05b4b4896af615564...  2017-01
#
#                       Reported by                    Falls within  Longitude  \
# 0  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.494870
# 1  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.513308
# 2  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.495055
# 3  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.509384
# 4  Avon and Somerset Constabulary  Avon and Somerset Constabulary  -2.515072
#
#     Latitude                                 Location  LSOA code  \
# ...

# %%
df.isnull().sum()
# Out:
# Crime ID                  2391
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                 1979
# Latitude                  1979
# Location                     0
# LSOA code                 1979
# LSOA name                 1979
# Crime type                   0
# Last outcome category     2391
# Context                  13688
# dtype: int64

# %%
df1 = df1[pd.notnull(df1['Latitude'])]
df1.head(20)
# Out:
#                                              Crime ID    Month  \
# 0                                                 NaN  2017-01
# 1                                                 NaN  2017-01
# 2                                                 NaN  2017-01
# 3                                                 NaN  2017-01
# 4                                                 NaN  2017-01
# 5                                                 NaN  2017-01
# 6                                                 NaN  2017-01
# 7                                                 NaN  2017-01
# 8                                                 NaN  2017-01
# 9                                                 NaN  2017-01
# 10                                                NaN  2017-01
# 11                                                NaN  2017-01
# 12  a526e7399ba9ff64531b97d89d3267ea1b5ef997d0b84e...  2017-01
# 13  aeb7bbbe699c92e4049a075849f31cde8a113e27d96f70...  2017-01
# ...

# %%
sns.factorplot(
    y='Last outcome category',
    data=df,
    col='Crime type',
    kind='count',
    col_wrap=3
).set_axis_labels('# of such cases','Last outcome category');

# %%
sns.factorplot(
    y='Crime type',
    data=df,
    kind='count',
).set_axis_labels('# of such cases','Crime type');

# %%
df1 = df1.filter(['Longitude','Latitude'], axis=1)
df1.head()
# Out:
#    Longitude   Latitude
# 0  -1.238996  54.711419
# 1  -1.239872  54.713537
# 2  -1.235446  54.711190
# 3  -1.235813  54.708973
# 4  -1.236116  54.711859

# %%
a1 = df1['Longitude'].values
a2 = df1['Latitude'].values
X = np.array(list(zip(a1, a2)))
plt.scatter(a1, a2, c='green', s=9)

# %%
df1.isnull().sum()
# Out:
# Longitude    0
# Latitude     0
# dtype: int64

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4).fit(X)

# %%
C = kmeans.cluster_centers_

# %%
y_pred = kmeans.predict(X)
# plot the cluster assignments and cluster centers
plt.scatter(a1, a2, c=y_pred, cmap="plasma")
plt.scatter(kmeans.cluster_centers_[:, 0],   
            kmeans.cluster_centers_[:, 1],
            marker='*', 
            c='red', 
            s=100, 
            linewidth=2,
            cmap="plasma")
